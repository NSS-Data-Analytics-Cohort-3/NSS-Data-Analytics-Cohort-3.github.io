# %%
import os
import pandas as pd
import json

# %%
website_info = pd.read_csv('../Website.csv', encoding='latin1')
website_info.head()
# Out:
#      First        Last                      Email  \
# 0    Aaron    Plunkett       aaroncpjob@gmail.com
# 1   Andrew       Konig          drewdat@gmail.com
# 2  Bethany  Dillingham      dillinghamb@gmail.com
# 3   Daniel      Newton  d.curtis.newton@gmail.com
# 4   Dustin       Bowen           drobo@posteo.net
#
#                                Professional Headshot Fun Photo  \
# 0  https://drive.google.com/file/d/1t9f4ppFXSESPn...       NaN
# 1                                                  y       NaN
# 2  https://drive.google.com/file/d/1eBVaafXMDsEk8...       NaN
# 3  https://drive.google.com/file/d/1yCNK2Ch4T9H5J...       NaN
# 4  https://drive.google.com/file/d/15jXh_v95p5ICP...       NaN
#
#                                 Github  \
# 0           https://github.com/aaroncp
# 1         https://github.com/drewkonig
# 2            https://github.com/bdilla
# 3  https://github.com/DanielNewton1989
# 4           https://github.com/d-bowen
#
#                                             LinkedIn  Capstone (video)  \
# 0          https://www.linkedin.com/in/aaronplunkett               NaN
# 1            https://www.linkedin.com/in/drew-konig/               NaN
# 2           https://www.linkedin.com/in/dillinghamb/               NaN
# 3  https://www.linkedin.com/in/daniel-newton-6074...               NaN
# 4                 www.linkedin.com/in/dustin-r-bowen               NaN
#
#    Podcast iframe PDF Resume  ... Unnamed: 22  Unnamed: 23 Unnamed: 24  \
# 0             NaN        NaN  ...         NaN          NaN         NaN
# 1             NaN        NaN  ...         NaN          NaN         NaN
# 2             NaN        NaN  ...         NaN          NaN         NaN
# 3             NaN        NaN  ...         NaN          NaN         NaN
# 4             NaN        NaN  ...         NaN          NaN         NaN
#
#    Unnamed: 25 Unnamed: 26 Unnamed: 27  Unnamed: 28  Unnamed: 29  Unnamed: 30  \
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 1          NaN         NaN         NaN          NaN          NaN          NaN
# 2          NaN         NaN         NaN          NaN          NaN          NaN
# 3          NaN         NaN         NaN          NaN          NaN          NaN
# 4          NaN         NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 31
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 32 columns]

# %%
website_info = website_info.head(14)
website_info.shape
# Out:
# (14, 32)

# %%
website_info = website_info.iloc[:, 0:16]
website_info
# Out:
#             First         Last                      Email  \
# 0           Aaron     Plunkett       aaroncpjob@gmail.com
# 1          Andrew        Konig          drewdat@gmail.com
# 2         Bethany   Dillingham      dillinghamb@gmail.com
# 3          Daniel       Newton  d.curtis.newton@gmail.com
# 4          Dustin        Bowen           drobo@posteo.net
# 5           Dylan        Smith   jeffdylansmith@gmail.com
# 6         Jessica     Morrison        jnicomorr@gmail.com
# 7         Kristen        Lucas      kristenw629@gmail.com
# 8            Kyle       Yandow      kylejyandow@gmail.com
# 9            Mark      Koivula     mkoivula6515@gmail.com
# 10        Maureen    Caballero       maureencab@gmail.com
# 11        Natalia  Zemchikhina      natalulik@hotmail.com
# 12         Philip     Campbell   campbell.phil8@gmail.com
# 13  Wai Mai Lydia        Tsang         wmltsang@gmail.com
#
#                                 Professional Headshot  \
# 0   https://drive.google.com/file/d/1t9f4ppFXSESPn...
# 1                                                   y
# 2   https://drive.google.com/file/d/1eBVaafXMDsEk8...
# 3   https://drive.google.com/file/d/1yCNK2Ch4T9H5J...
# 4   https://drive.google.com/file/d/15jXh_v95p5ICP...
# 5   https://drive.google.com/file/d/1inFnlqY-PmhIr...
# 6   https://drive.google.com/drive/folders/13z_2E4...
# 7                                                   y
# 8   https://drive.google.com/file/d/1zIV9LHfRZqPaj...
# 9   https://drive.google.com/file/d/1RXd1JSGnAzdpV...
# 10                                        transferred
# 11                                        transferred
# 12  https://drive.google.com/file/d/1YkgvA2bFF2k8u...
# 13  https://drive.google.com/file/d/1ZEj1VVT2hTlwZ...
#
#                                             Fun Photo  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                   y
# 8   https://drive.google.com/file/d/1idq9aNDAlWSRO...
# 9                                                 NaN
# 10                                        transferred
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                  Github  \
# 0            https://github.com/aaroncp
# 1          https://github.com/drewkonig
# 2             https://github.com/bdilla
# 3   https://github.com/DanielNewton1989
# 4            https://github.com/d-bowen
# 5      http://github.com/jeffdylansmith
# 6      https://github.com/Jess-Morrison
# 7       https://github.com/KristenLucas
# 8            https://github.com/KYandow
# 9        https://github.com/MarkKoivula
# 10  https://github.com/maureencaballero
# 11        https://github.com/nataliaz87
# 12     https://github.com/philton-maker
# 13          https://github.com/wmltsang
#
#                                              LinkedIn  Capstone (video)  \
# 0           https://www.linkedin.com/in/aaronplunkett               NaN
# 1             https://www.linkedin.com/in/drew-konig/               NaN
# 2            https://www.linkedin.com/in/dillinghamb/               NaN
# 3   https://www.linkedin.com/in/daniel-newton-6074...               NaN
# 4                  www.linkedin.com/in/dustin-r-bowen               NaN
# 5              http://linkedin.com/in/jeffdylansmith/               NaN
# 6   https://www.linkedin.com/in/jessica-morrison-8...               NaN
# 7   https://www.linkedin.com/in/kristen-lucas-b152...               NaN
# 8                      https://tinyurl.com/k-j-yandow               NaN
# 9         : https://www.linkedin.com/in/mark-koivula/               NaN
# 10  https://www.linkedin.com/in/maureen-caballero-...               NaN
# 11   https://www.linkedin.com/in/natalia-zemchikhina/               NaN
# 12             www.linkedin.com/in/phil-campbell-2015               NaN
# 13                         linkedin.com/in/lydiatsang               NaN
#
#     Podcast iframe                                         PDF Resume  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# 5              NaN  https://drive.google.com/file/d/1kS0NCoODAV94m...
# 6              NaN                                                NaN
# 7              NaN                                                NaN
# 8              NaN  https://drive.google.com/file/d/1uLN9MUNe-UcZY...
# 9              NaN                                                NaN
# 10             NaN                                                NaN
# 11             NaN                                                NaN
# 12             NaN  https://drive.google.com/file/d/1vDtz4uv4FIf2w...
# 13             NaN                                                NaN
#
#    Is Job Searching  Capstone (link)                   Personal Site  \
# 0                 N              NaN                             NaN
# 1                 Y              NaN                             NaN
# 2                 Y              NaN                             NaN
# 3                 Y              NaN                             NaN
# 4                 N              NaN                             NaN
# 5                 N              NaN                             NaN
# 6                 y              NaN                             NaN
# 7                 Y              NaN                             NaN
# 8                 Y              NaN                             NaN
# 9                 Y              NaN                             NaN
# 10                N              NaN                             NaN
# 11                N              NaN                             NaN
# 12                Y              NaN                             NaN
# 13                Y              NaN  https://lydiatsang.weebly.com/
#
#     Website Portfolio                                            Tagline  \
# 0                 NaN  Information is the oil of the 21st century, a...
# 1                 NaN  Cash is King. Information is his twin. - Sot...
# 2                 NaN              Like bringing a knife to a Data fight
# 3                 NaN  "I care about 3 things: the facts, the facts, ...
# 4                 NaN                                    Let's find out.
# 5                 NaN                         "It's all data these days"
# 6                 NaN                       "Never argue with the data"
# 7                 NaN              "This IS the data you're looking for"
# 8                 NaN  Not a painter conjuring an image from air, but...
# 9                 NaN            "There is no such thing as too much QA"
# 10                NaN  "Without data, you are just another person wit...
# 11                NaN  "Do not believe everything you read on the Int...
# 12                NaN            "All (data) roads lead to (data) Rome."
# 13                NaN  "Things get done only if the data we gather ca...
#
#                                                   Bio
# 0   As a software developer, I've seen first hand ...
# 1   Coming from a retail background, I was always ...
# 2   During my time working in music business and h...
# 3   I would really enjoy waking up every day and g...
# 4   I've always enjoyed problem solving. I chose N...
# 5   I am a full stack developer hoping to bring my...
# 6   Hello there! My name is Jessica Morrison and I...
# 7   After working in the coffee shop world for ove...
# 8   Through a career working in the performing art...
# 9   Through my previous work experience as both a ...
# 10  As a manager at Panera Bread, my favorite part...
# 11  My military background in finance and work exp...
# 12  After college, I wound up playing music and ba...
# 13  I am a thorough and meticulous Data Analyst sp...

# %%
website_info.columns
# Out:
# Index(['First', 'Last', 'Email', 'Professional Headshot', 'Fun Photo',
#        'Github', 'LinkedIn', 'Capstone (video)', 'Podcast iframe',
#        'PDF Resume', 'Is Job Searching', 'Capstone (link)', 'Personal Site',
#        'Website Portfolio', 'Tagline', 'Bio'],
#       dtype='object')

# %% [markdown]
# ---
#
# Rename the columns to something that can be ingested by the js

# %%
column_map = {
    'First': 'firstName',
    'Last': 'lastName',
    'Tagline': 'reelThemIn',
    'Bio': 'bio',
    'Github': 'github',
    'LinkedIn': 'linkedin',
    'Is Job Searching': 'job_searching',
    'Website Portfolio': 'portfolio',
    'Capstone (video)': 'capstoneVideo',
    'Podcast iframe': 'podcast'
}

website_info = website_info.rename(column_map, axis=1)
website_info = website_info[column_map.values()]

website_info.columns
# Out:
# Index(['firstName', 'lastName', 'reelThemIn', 'bio', 'github', 'linkedin',
#        'job_searching', 'portfolio', 'capstoneVideo', 'podcast'],
#       dtype='object')

# %% [markdown]
# ---
#
# Make the paragraphs

# %%
def html_paragraph(v):
    if pd.isna(v):
        return ""
    return str(v)


website_info['reelThemIn'] = website_info['reelThemIn'].apply(html_paragraph)
website_info['bio'] = website_info['bio'].apply(html_paragraph)

# %% [markdown]
# ---
#
# Clean up some excess characters

# %%
for col in website_info.columns:
    try:
        website_info[col] = website_info[col] \
            .str.replace('“', '"') \
            .str.replace('”', '"') \
            .str.replace("’", "'") \
            .str.replace("—", "-")
    except:
        pass

# %% [markdown]
# ---
#
# Gather the image paths

# %%
def image_path(name, idx):
    return f"../assets/img/resized/{name.lower()}{idx}.jpeg"


website_info['proImg'] = website_info['firstName'].apply(image_path, idx=1)
website_info['funImg'] = website_info['firstName'].apply(image_path, idx=2)

# %%
website_info['proImg'].head()
# Out:
# 0      ../assets/img/resized/aaron1.jpeg
# 1     ../assets/img/resized/andrew1.jpeg
# 2    ../assets/img/resized/bethany1.jpeg
# 3     ../assets/img/resized/daniel1.jpeg
# 4     ../assets/img/resized/dustin1.jpeg
# Name: proImg, dtype: object

# %% [markdown]
# ---
#
# Resume paths

# %%
def resume_path(name):
    path = f"../assets/resume/{name.lower()}.pdf"
    if os.path.exists(path):
        return path


website_info['resume'] = website_info['firstName'].apply(resume_path)
website_info[['firstName', 'resume']]
# Out:
#         firstName                              resume
# 0           Aaron                                None
# 1          Andrew                                None
# 2         Bethany        ../assets/resume/bethany.pdf
# 3          Daniel         ../assets/resume/daniel.pdf
# 4          Dustin         ../assets/resume/dustin.pdf
# 5           Dylan          ../assets/resume/dylan.pdf
# 6         Jessica        ../assets/resume/jessica.pdf
# 7         Kristen        ../assets/resume/kristen.pdf
# 8            Kyle           ../assets/resume/kyle.pdf
# 9            Mark           ../assets/resume/mark.pdf
# 10        Maureen        ../assets/resume/maureen.pdf
# 11        Natalia        ../assets/resume/natalia.pdf
# 12         Philip         ../assets/resume/philip.pdf
# 13  Wai Mai Lydia  ../assets/resume/wai mai lydia.pdf

# %% [markdown]
# ---
#
# Assign Ids

# %%
website_info['id'] = website_info.index + 1

# %% [markdown]
# ---
#
# Take a peek

# %%
website_info.head(1)
# Out:
#   firstName  lastName                                         reelThemIn  \
# 0     Aaron  Plunkett  Information is the oil of the 21st century, a...
#
#                                                  bio  \
# 0  As a software developer, I've seen first hand ...
#
#                        github                                   linkedin  \
# 0  https://github.com/aaroncp  https://www.linkedin.com/in/aaronplunkett
#
#   job_searching  portfolio  capstoneVideo  podcast  \
# 0             N        NaN            NaN      NaN
#
#                               proImg                             funImg  \
# 0  ../assets/img/resized/aaron1.jpeg  ../assets/img/resized/aaron2.jpeg
#
#   resume  id
# 0   None   1

# %%
website_info.to_json("./../data/cohort.json", orient='records')
